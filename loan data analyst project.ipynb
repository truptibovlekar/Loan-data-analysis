# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("C:/Users/trupti bovlekar/Downloads/Python_projects/Python_projects/Loan_data_analysis_project/Loan_dataset.csv")
df
# Out:
#                                      Loan ID  \
# 0       14dd8831-6af5-400b-83ec-68e61888a048
# 1       4771cc26-131a-45db-b5aa-537ea4ba5342
# 2       4eed4e6a-aa2f-4c91-8651-ce984ee8fb26
# 3       77598f7b-32e7-4e3b-a6e5-06ba0d98fe8a
# 4       d4062e70-befa-4995-8643-a0de73938182
# ...                                      ...
# 100509                                   NaN
# 100510                                   NaN
# 100511                                   NaN
# 100512                                   NaN
# 100513                                   NaN
#
#                                  Customer ID Loan Status  Current Loan Amount  \
# 0       981165ec-3274-42f5-a3b4-d104041a9ca9  Fully Paid             445412.0
# 1       2de017a3-2e01-49cb-a581-08169e83be29  Fully Paid             262328.0
# 2       5efb2b2b-bf11-4dfd-a572-3761a2694725  Fully Paid           99999999.0
# 3       e777faab-98ae-45af-9a86-7ce5b33b1011  Fully Paid             347666.0
# ...

# %%
df.columns
# Out:
# Index(['Loan ID', 'Customer ID', 'Loan Status', 'Current Loan Amount', 'Term',
#        'Credit Score', 'Annual Income', 'Years in current job',
#        'Home Ownership', 'Purpose', 'Monthly Debt', 'Years of Credit History',
#        'Months since last delinquent', 'Number of Open Accounts',
#        'Number of Credit Problems', 'Current Credit Balance',
#        'Maximum Open Credit', 'Bankruptcies', 'Tax Liens'],
#       dtype='object')

# %%
# 1.What is the average current loan amount for each loan status?
# Group by 'Loan Status' and calculate the mean of 'Current Loan Amount'
avg_loan_by_status = df.groupby('Loan Status')['Current Loan Amount'].mean()
print(avg_loan_by_status)
# Out:
# Loan Status
# Charged Off    3.249752e+05
# Fully Paid     1.510694e+07
# Name: Current Loan Amount, dtype: float64

# %%
# 2. How does the credit score vary with the annual income?

# Scatter plot: Credit Score vs Annual Income
plt.figure(figsize=(8, 5))
sns.scatterplot(data=df, x='Annual Income', y='Credit Score')
plt.title('Credit Score vs Annual Income')
plt.xlabel('Annual Income')
plt.ylabel('Credit Score')
plt.show()

# %%
# 3. Is there a correlation between the number of open accounts and the current credit balance?

# Scatter plot: Open Accounts vs Current Credit Balance
plt.figure(figsize=(8, 5))
sns.scatterplot(data=df, x='Number of Open Accounts', y='Current Credit Balance')
plt.title('Open Accounts vs Current Credit Balance')
plt.xlabel('Number of Open Accounts')
plt.ylabel('Current Credit Balance')
plt.show()

# %%
# 4. What is the distribution of credit scores across different home ownership types?

# Box plot: Credit Score by Home Ownership
plt.figure(figsize=(8, 5))
sns.boxplot(data=df, x='Home Ownership', y='Credit Score')
plt.title('Credit Score by Home Ownership')
plt.xlabel('Home Ownership')
plt.ylabel('Credit Score')
plt.xticks(rotation=45)
plt.show()

# %%
# 5. How does the annual income differ for different purposes of loans?

# Box plot: Annual Income by Purpose
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='Purpose', y='Annual Income')
plt.title('Annual Income by Loan Purpose')
plt.xlabel('Purpose')
plt.ylabel('Annual Income')
plt.xticks(rotation=45)
plt.show()

# %%
# 6. What is the average monthly debt for each term (short-term vs. long-term)?

# Group by Term and calculate mean of Monthly Debt
avg_monthly_debt = df.groupby('Term')['Monthly Debt'].mean()
print(avg_monthly_debt)
# Out:
# Term
# Long Term     21585.664968
# Short Term    17274.158442
# Name: Monthly Debt, dtype: float64

# %%
# 7. Is there a relationship between years of credit history and current credit balance?

# Scatter plot: Years of Credit History vs Current Credit Balance
plt.figure(figsize=(8, 5))
sns.scatterplot(data=df, x='Years of Credit History', y='Current Credit Balance')
plt.title('Credit History vs Current Credit Balance')
plt.xlabel('Years of Credit History')
plt.ylabel('Current Credit Balance')
plt.show()

# %%
# 8. How does the credit score vary with years in the current job?

# Box plot: Credit Score by Years in Current Job
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='Years in current job', y='Credit Score')
plt.title('Credit Score by Years in Current Job')
plt.xlabel('Years in Current Job')
plt.ylabel('Credit Score')
plt.xticks(rotation=45)
plt.show()

# %%
# 9. What is the relationship between number of credit problems and number of open accounts?

# Scatter plot: Credit Problems vs Open Accounts
plt.figure(figsize=(8, 5))
sns.scatterplot(data=df, x='Number of Credit Problems', y='Number of Open Accounts')
plt.title('Credit Problems vs Open Accounts')
plt.xlabel('Number of Credit Problems')
plt.ylabel('Number of Open Accounts')
plt.show()

# %%
# 10. What is the distribution of annual income across different loan statuses?

# Box plot: Annual Income by Loan Status
plt.figure(figsize=(8, 5))
sns.boxplot(data=df, x='Loan Status', y='Annual Income')
plt.title('Annual Income by Loan Status')
plt.xlabel('Loan Status')
plt.ylabel('Annual Income')
plt.xticks(rotation=45)
plt.show()

# %%
# 11. Is there a correlation between the current loan amount and the number of open accounts?
# Scatter plot: Current Loan Amount vs Number of Open Accounts
plt.figure(figsize=(8, 5))
sns.scatterplot(data=df, x='Number of Open Accounts', y='Current Loan Amount')
plt.title('Current Loan Amount vs Number of Open Accounts')
plt.xlabel('Number of Open Accounts')
plt.ylabel('Current Loan Amount')
plt.show()

# %%
# 12. How does the monthly debt vary with the years of credit history?

# Scatter plot: Years of Credit History vs Monthly Debt
plt.figure(figsize=(8, 5))
sns.scatterplot(data=df, x='Years of Credit History', y='Monthly Debt')
plt.title('Monthly Debt vs Years of Credit History')
plt.xlabel('Years of Credit History')
plt.ylabel('Monthly Debt')
plt.show()

# %%
# 13. What is the average annual income for each purpose of loan?

# Group by Purpose and calculate mean of Annual Income
avg_income_purpose = df.groupby('Purpose')['Annual Income'].mean()
print(avg_income_purpose)
# Out:
# Purpose
# Business Loan           1.591963e+06
# Buy House               1.495251e+06
# Buy a Car               1.220353e+06
# Debt Consolidation      1.362464e+06
# Educational Expenses    1.071051e+06
# Home Improvements       1.667437e+06
# Medical Bills           1.409286e+06
# Other                   1.348516e+06
# Take a Trip             1.219899e+06
# major_purchase          1.430753e+06
# moving                  1.591375e+06
# other                   1.286008e+06
# renewable_energy        1.473740e+06
# small_business          1.547456e+06
# vacation                1.155290e+06
# wedding                 1.464233e+06
# Name: Annual Income, dtype: float64

# %%
# 14. How does the credit score vary with the number of credit problems?

# Box plot: Credit Score by Number of Credit Problems
plt.figure(figsize=(8, 5))
sns.boxplot(data=df, x='Number of Credit Problems', y='Credit Score')
plt.title('Credit Score by Number of Credit Problems')
plt.xlabel('Number of Credit Problems')
plt.ylabel('Credit Score')
plt.show()

# %%
# 15. Is there a correlation between the number of credit problems and the current credit balance?

# Scatter plot: Credit Problems vs Current Credit Balance
plt.figure(figsize=(8, 5))
sns.scatterplot(data=df, x='Number of Credit Problems', y='Current Credit Balance')
plt.title('Credit Problems vs Current Credit Balance')
plt.xlabel('Number of Credit Problems')
plt.ylabel('Current Credit Balance')
plt.show()

# %%
# 16. What is the distribution of current loan amounts across different home ownership types?

# Box plot: Current Loan Amount by Home Ownership
plt.figure(figsize=(8, 5))
sns.boxplot(data=df, x='Home Ownership', y='Current Loan Amount')
plt.title('Loan Amount by Home Ownership')
plt.xlabel('Home Ownership')
plt.ylabel('Current Loan Amount')
plt.xticks(rotation=45)
plt.show()

# %%
# 17. How does the annual income vary with the years in the current job?

# Box plot: Annual Income by Years in Current Job
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='Years in current job', y='Annual Income')
plt.title('Annual Income by Years in Current Job')
plt.xlabel('Years in Current Job')
plt.ylabel('Annual Income')
plt.xticks(rotation=45)
plt.show()

# %%
# 18. Is there a correlation between the current loan amount and the monthly debt?
# Scatter plot: Current Loan Amount vs Monthly Debt
plt.figure(figsize=(8, 5))
sns.scatterplot(data=df, x='Monthly Debt', y='Current Loan Amount')
plt.title('Loan Amount vs Monthly Debt')
plt.xlabel('Monthly Debt')
plt.ylabel('Current Loan Amount')
plt.show()

# %%
# 19. What is the average monthly debt for each home ownership type?
# Group by Home Ownership and calculate mean of Monthly Debt
avg_debt_home = df.groupby('Home Ownership')['Monthly Debt'].mean()
print(avg_debt_home)
# Out:
# Home Ownership
# HaveMortgage     18541.776822
# Home Mortgage    21072.059467
# Own Home         17060.082101
# Rent             15796.777284
# Name: Monthly Debt, dtype: float64

# %%
# 20. How does the credit score vary with the number of open accounts?

# Box plot: Credit Score by Number of Open Accounts
plt.figure(figsize=(8, 5))
sns.boxplot(data=df, x='Number of Open Accounts', y='Credit Score')
plt.title('Credit Score by Open Accounts')
plt.xlabel('Number of Open Accounts')
plt.ylabel('Credit Score')
plt.show()

# %%
# 21. What is the distribution of credit scores across different loan statuses?

# Box plot: Credit Score by Loan Status
plt.figure(figsize=(8, 5))
sns.boxplot(data=df, x='Loan Status', y='Credit Score')
plt.title('Credit Score by Loan Status')
plt.xlabel('Loan Status')
plt.ylabel('Credit Score')
plt.xticks(rotation=45)
plt.show()

# %%
# 22. Is there a correlation between the current loan amount and the years of credit history?
# Scatter plot: Years of Credit History vs Current Loan Amount
plt.figure(figsize=(8, 5))
sns.scatterplot(data=df, x='Years of Credit History', y='Current Loan Amount')
plt.title('Loan Amount vs Years of Credit History')
plt.xlabel('Years of Credit History')
plt.ylabel('Current Loan Amount')
plt.show()

# %%
# 22. Is there a correlation between the current loan amount and the years of credit history?

# Scatter plot: Years of Credit History vs Current Loan Amount
plt.figure(figsize=(8, 5))
sns.scatterplot(data=df, x='Years of Credit History', y='Current Loan Amount')
plt.title('Loan Amount vs Years of Credit History')
plt.xlabel('Years of Credit History')
plt.ylabel('Current Loan Amount')
plt.show()

# %%
# 24. What is the average current loan amount for each purpose of loan?
# Group by Purpose and calculate mean of Current Loan Amount
avg_loan_purpose = df.groupby('Purpose')['Current Loan Amount'].mean()
print(avg_loan_purpose)
# Out:
# Purpose
# Business Loan           7.837789e+06
# Buy House               1.106036e+07
# Buy a Car               1.414682e+07
# Debt Consolidation      1.180683e+07
# Educational Expenses    1.428536e+07
# Home Improvements       1.252117e+07
# Medical Bills           1.179902e+07
# Other                   1.253627e+07
# Take a Trip             1.111667e+07
# major_purchase          1.298956e+07
# moving                  1.350072e+07
# other                   1.059243e+07
# renewable_energy        1.975534e+05
# small_business          9.484232e+06
# vacation                7.058680e+06
# wedding                 1.760299e+07
# Name: Current Loan Amount, dtype: float64

# %%
# 25. How does the credit score vary with the current credit balance?
# Scatter plot: Credit Score vs Current Credit Balance
plt.figure(figsize=(8, 5))
sns.scatterplot(data=df, x='Current Credit Balance', y='Credit Score')
plt.title('Credit Score vs Current Credit Balance')
plt.xlabel('Current Credit Balance')
plt.ylabel('Credit Score')
plt.show()

# %%
# 26. Is there a correlation between the annual income and the current credit balance?
# Scatter plot: Annual Income vs Current Credit Balance
plt.figure(figsize=(8, 5))
sns.scatterplot(data=df, x='Annual Income', y='Current Credit Balance')
plt.title('Annual Income vs Current Credit Balance')
plt.xlabel('Annual Income')
plt.ylabel('Current Credit Balance')
plt.show()

# %%
# 27. What is the distribution of annual income across different terms (short-term vs. long-term)?

# Box plot: Annual Income by Loan Term
plt.figure(figsize=(8, 5))
sns.boxplot(data=df, x='Term', y='Annual Income')
plt.title('Annual Income by Loan Term')
plt.xlabel('Loan Term')
plt.ylabel('Annual Income')
plt.show()

# %%
# 28. How does the credit score vary with the number of credit problems?

# Box plot: Credit Score by Number of Credit Problems
plt.figure(figsize=(8, 5))
sns.boxplot(data=df, x='Number of Credit Problems', y='Credit Score')
plt.title('Credit Score by Number of Credit Problems')
plt.xlabel('Number of Credit Problems')
plt.ylabel('Credit Score')
plt.show()

# %%
# 29. Is there a correlation between the current loan amount and the number of credit problems?

# Scatter plot: Credit Problems vs Current Loan Amount
plt.figure(figsize=(8, 5))
sns.scatterplot(data=df, x='Number of Credit Problems', y='Current Loan Amount')
plt.title('Loan Amount vs Number of Credit Problems')
plt.xlabel('Number of Credit Problems')
plt.ylabel('Current Loan Amount')
plt.show()

# %%
# 30. What is the relationship between the number of open accounts and the years of credit history?

# Scatter plot: Years of Credit History vs Number of Open Accounts
plt.figure(figsize=(8, 5))
sns.scatterplot(data=df, x='Years of Credit History', y='Number of Open Accounts')
plt.title('Years of Credit History vs Open Accounts')
plt.xlabel('Years of Credit History')
plt.ylabel('Number of Open Accounts')
plt.show()
